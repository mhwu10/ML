# %% [markdown]
# # Dogs vs. Cats
# The training and testing data of this project is from a kaggle competetion https://www.kaggle.com/competitions/dogs-vs-cats. \
# The goal of this project is to correctly recognise pictures of dogs and cats.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models
from torchvision.utils import make_grid
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
# # This cell is used on kaggle for unzip the dataset from the competition 
# # https://www.kaggle.com/competitions/dogs-vs-cats
# silent the following commands if the data already exists
# ! unzip "../input/dogs-vs-cats/train.zip" -d dogs-vs-cats
# ! unzip "../input/dogs-vs-cats/test1.zip" -d dogs-vs-cats
# !mv ./dogs-vs-cats/train ./dogs-vs-cats/orig_train

# %% [markdown]
# The directory tree of original data is
# <pre>.
# └── data
#      ├── test
#      │    ├── cat.jpg
#      │    └── dog.jpg (12,500 files in total)
#      │
#      └── train
#           ├── cat.jpg
#           └── dog.jpg (25,000 files in total)
# </pre>
#
# For easily running the calculation, the following cell is to convert the directory tree into as
# <pre>.
# └── data
#      ├── test
#      │    ├── cat.jpg
#      │    └── dog.jpg (12,500 files in total)
#      │
#      └── original_train
#           ├── train
#           │    ├── cat.jpg
#           │    └── dog.jpg (20,000 files in total)
#           └── validation
#                ├── cat.jpg
#                └── dog.jpg (5,000 files in total)
# </pre>
#
# If the original directory tree already works well, then mute the next cell.

# %%
import shutil
rootdir= './dogs-vs-cats' #path of the original folder

if os.path.exists(rootdir) == False:
    os.makedirs(rootdir +'/train/')
    os.makedirs(rootdir +'/validation/')
    source = rootdir + '/orig_train'

    allFileNames = os.listdir(source)
    print(allFileNames[:10])
    np.random.shuffle(allFileNames)

    val_ratio = 0.2

    train_FileNames, val_FileNames = np.split(np.array(allFileNames), [int(len(allFileNames)* (1 - val_ratio))])

    train_FileNames = [source+'/'+ name for name in train_FileNames.tolist()]
    val_FileNames = [source+'/' + name for name in val_FileNames.tolist()]

    for name in train_FileNames:
        try:
            shutil.copy(name, rootdir +'/train')
        except:
            print(name)

    for name in val_FileNames:
        try:
            shutil.copy(name, rootdir +'/validation')
        except:
            print(name)

# %%
# check
print(len(os.listdir(rootdir +'/orig_train/')))
print(len(os.listdir(rootdir +'/train/')))
print(len(os.listdir(rootdir +'/validation/')))
# Out:
# 25001
# 25000
# 5000

# %% [markdown]
# # Data augmentation
# Here is doing a variety of transformation for data augmentation such rotate, flip, etc, and normalisation.

# %%
# Examne the data
import os
from PIL import Image
from IPython.display import display

# Filter harmless warnings
import warnings
warnings.filterwarnings("ignore")

# %%
dog = Image.open(rootdir+'/orig_train/'+'/dog.7603.jpg')
print(dog.size)
display(dog)
# Out:
# (416, 426)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=416x426>

# %%
r, g, b = dog.getpixel((0, 0))
print(r,g,b)
# Out:
# 103 144 162

# %%
transform = transforms.Compose([
    transforms.ToTensor()
])
im = transform(dog)
print(im.shape)
plt.imshow(np.transpose(im.numpy(), (1, 2, 0)));
# Out:
# torch.Size([3, 426, 416])

# %% [markdown]
# Pytorch automatically loads the [0. 255] of range of RGB to [0, 1], so the RGB in the following process is normalised.

# %%
im[:,0,0]
# Out:
# tensor([0.4039, 0.5647, 0.6353])

# %% [markdown]
# ### Transforms
# All pictures are not in the same format, so we need to transform them into an apropriate format for further training our model.

# %%
# resize 
transform = transforms.Compose([
    transforms.Resize(224),  # resize shortest side to 224 pixel, this command also works for making small picture bigger
    transforms.ToTensor()
])
im = transform(dog)
print(im.shape)
plt.imshow(np.transpose(im.numpy(), (1, 2, 0)));
# Out:
# torch.Size([3, 229, 224])

# %%
# centercrop
#If size is an integer instead of sequence like (h, w), a square crop of (size, size) is made.

transform = transforms.Compose([
    transforms.CenterCrop(224), 
    transforms.ToTensor()
])
im = transform(dog) # this crops the original image
print(im.shape)
plt.imshow(np.transpose(im.numpy(), (1, 2, 0)));
# Out:
# torch.Size([3, 224, 224])

# %%
# combine the above two steps
transform = transforms.Compose([
    transforms.Resize(224),
    transforms.CenterCrop(224), 
    transforms.ToTensor()
])
im = transform(dog)
print(im.shape)
plt.imshow(np.transpose(im.numpy(), (1, 2, 0)));
# Out:
# torch.Size([3, 224, 224])

# %%
# horizontal flip
transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=1),  # default p=0.5
    transforms.ToTensor()
])
im = transform(dog)
print(im.shape)
plt.imshow(np.transpose(im.numpy(), (1, 2, 0)));
# Out:
# torch.Size([3, 426, 416])

# %%
# rotate

transform = transforms.Compose([
    transforms.RandomRotation(30),  # rotate randomly between +/- 30 degrees
    transforms.ToTensor()
])
im = transform(dog)
print(im.shape)
plt.imshow(np.transpose(im.numpy(), (1, 2, 0)));
# Out:
# torch.Size([3, 426, 416])

# %%
# scaling for different axis can be done by resize

transform = transforms.Compose([
    transforms.Resize((224,224)),  # be sure to pass in a list or a tuple
    transforms.ToTensor()
])
im = transform(dog)
print(im.shape)
plt.imshow(np.transpose(im.numpy(), (1, 2, 0)));
# Out:
# torch.Size([3, 224, 224])

# %% [markdown]
# ### Normalisation
# Once the image is converted into tensor, we are able to perform normalisation on it. This serve to make convergence happen faster during training. The values are somewhat arbitrary - you can use a mean of 0.5 and a standard deviation of 0.5 to convert a range of [0,1] to [-1,1], for example.<br>However, <a href='https://discuss.pytorch.org/t/normalization-in-the-mnist-example/457/22'>research has shown</a> that mean=[0.485, 0.456, 0.406] and std=[0.229, 0.224, 0.225] work well in practice.
#
# The transformation will be done for each channel of the input tensor as\
# $\quad\textrm {input[channel]} = \frac{\textrm{input[channel] - mean[channel]}}{\textrm {std[channel]}}$

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])
im = transform(dog)
print(im.shape)
plt.imshow(np.transpose(im.numpy(), (1, 2, 0)));
# Out:
# torch.Size([3, 426, 416])

# %%
# After normalization:
im[:,0,0]
# Out:
# tensor([-0.3541,  0.4853,  1.0191])

# %%
# de-normalisation for seeing the image back

inv_normalize = transforms.Normalize(
    mean=[-0.485/0.229, -0.456/0.224, -0.406/0.225],
    std=[1/0.229, 1/0.224, 1/0.225]
)
im_inv = inv_normalize(im)
plt.figure(figsize=(12,4))
plt.imshow(np.transpose(im_inv.numpy(), (1, 2, 0)));

# %%
# Note that the original tensor was not modified back

plt.figure(figsize=(12,4))
plt.imshow(np.transpose(im.numpy(), (1, 2, 0)));

# %% [markdown]
# # Define transformation for our calculation now

# %%
train_transform = transforms.Compose([
        transforms.RandomRotation(10),      # rotate +/- 10 degrees
        transforms.RandomHorizontalFlip(),  # reverse 50% of images
        transforms.Resize(224),             # resize shortest side to 224 pixels
        transforms.CenterCrop(224),         # crop longest side to 224 pixels at center
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ])

test_transform = transforms.Compose([
        transforms.Resize(224),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ])

# %% [markdown]
# ### Start by creating a list

# %%
from torch.utils.data import Dataset

# %% [markdown]
# ### Prepare training set, testing sets, and loaders

# %%
class myDataset(Dataset):
    
    def __init__(self,path,tfm=test_transform,files = None):
        super(myDataset).__init__()
        self.path = path
        self.files = sorted([os.path.join(path, x) for x in os.listdir(path) if x.endswith(".jpg")])
        if files != None:
            self.files = files
        print(f"One {path} sample",self.files[0])
        self.transform = tfm
  
    def __len__(self):
        return len(self.files)
  
    def __getitem__(self,idx):
        fname = self.files[idx]
        im = Image.open(fname)
        im = self.transform(im)
        #im = self.data[idx]
        try:
            label1 = fname.split("/")[-1].split(".")[0]
            if label1 == 'dog':
                label = 1
            elif label1 == 'cat':
                label = 0
        except:
            label = -1 # test has no label
        return im, label

# %%
batch_size = 10
_dataset_dir = "./dogs-vs-cats"
# Construct datasets.
# The argument "loader" tells how torchvision reads the data.
train_set = myDataset(os.path.join(_dataset_dir,"train"), tfm=train_transform)
train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=0, pin_memory=True)
valid_set = myDataset(os.path.join(_dataset_dir,"validation"), tfm=test_transform)
valid_loader = DataLoader(valid_set, batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=True)
# Out:
# One ./dogs-vs-cats/train sample ./dogs-vs-cats/train/cat.0.jpg
# One ./dogs-vs-cats/validation sample ./dogs-vs-cats/validation/cat.0.jpg

# %%
# Grab the first batch of 10 images
for images, labels in train_loader: 
    break

# Print the labels
print('Label:', labels.numpy())
# print('Class:', *np.array([class_names[i] for i in labels]))

im = make_grid(images, nrow=5)  # the default nrow is 8

# Inverse normalize the images
inv_normalize = transforms.Normalize(
    mean=[-0.485/0.229, -0.456/0.224, -0.406/0.225],
    std=[1/0.229, 1/0.224, 1/0.225]
)
im_inv = inv_normalize(im)

# Print the images
plt.figure(figsize=(12,4))
plt.imshow(np.transpose(im_inv.numpy(), (1, 2, 0)));
# Out:
# Label: [0 1 0 0 1 1 1 0 1 1]

# %% [markdown]
# # Define model
# We can define model by ourselve, or download a pre-trained model. \
# I first create model on my own.

# %%
class CNNClassifier(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 6, 3, 1)
        self.conv2 = nn.Conv2d(6, 16, 3, 1)
        self.fc1 = nn.Linear(54 * 54 * 16, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 2)

    def forward(self, X):
        X = F.relu(self.conv1(X))
        X = F.max_pool2d(X, 2, 2)
        X = F.relu(self.conv2(X))
        X = F.max_pool2d(X, 2, 2)
        X = X.view(-1, 54 * 54 * 16)
        X = F.relu(self.fc1(X))
        X = F.relu(self.fc2(X))
        X = self.fc3(X)
        return F.log_softmax(X, dim=1)

# %% [markdown]
# ### Setup other parameters

# %%
# This is for the progress bar if.
from tqdm.auto import tqdm
import random

_exp_name = "cat_dog"

# "cuda" only when GPUs are available.
device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)

model = CNNClassifier().to(device)

# For the classification task, we use cross-entropy as the measurement of performance.
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001) #, weight_decay=1e-5) 

model
# Out:
# cuda
# CNNClassifier(
#   (conv1): Conv2d(3, 6, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(6, 16, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=46656, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=2, bias=True)
# )

# %% [markdown]
# ### Train model

# %%
# train the model
import time
start_time = time.time()

epochs = 30
best_acc = 0
stale = 0 # recode stale steps for hitting patience
patience = 50 # If no improvement in 'patience' epochs, early stop

# control the number of imported data for time save, if needed
max_trn_batch = 800 
max_val_batch = 300

train_losses = []
valid_losses = []
train_correct = []
valid_correct = []

for i in range(epochs):
    trn_corr = 0
    val_corr = 0
    
    # Run the training batches
    for b, (X_train, y_train) in enumerate(train_loader):
        X_train, y_train = X_train.to(device), y_train.to(device)
        if b == max_trn_batch:
            break
        b+=1
        
        # Apply the model
        y_pred = model(X_train)
        loss = criterion(y_pred, y_train)
 
        # Tally the number of correct predictions
        predicted = torch.max(y_pred.data, 1)[1]
        batch_corr = (predicted == y_train).sum()
        trn_corr += batch_corr
        
        # Update parameters
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Print interim results
        if b%200 == 0:
            print(f'epoch: {i + 1:2}  training batch: {b:4} [{batch_size * b:6}/{batch_size * max_trn_batch:6}]  loss: {loss.item():10.8f}  accuracy: {trn_corr.item() / (batch_size * b) * 100:7.3f}%')

    train_losses.append(loss.item())
    train_correct.append(trn_corr.item())

    # Run the validation batches
    with torch.no_grad():
        for b, (X_test, y_test) in enumerate(valid_loader):
            X_test, y_test = X_test.to(device), y_test.to(device)
            if b == max_val_batch:
                break
            
            b += 1
            # Apply the model
            y_val = model(X_test)

            # Tally the number of correct predictions
            predicted = torch.max(y_val.data, 1)[1] 
            val_corr += (predicted == y_test).sum()
            
            if b%100 == 0:
                print(f'epoch: {i + 1:2}  validation batch: {b:4} [{batch_size * b:6}/{batch_size * max_val_batch:6}]  loss: {loss.item():10.8f}  accuracy: {val_corr.item() / (batch_size * b) * 100:7.3f}%')

    loss = criterion(y_val, y_test)
    valid_losses.append(loss.item())
    valid_correct.append(val_corr.item())
    
    # extract the accuracy for the present epoch
    val_acc = val_corr.item() / (batch_size * b)
    
    # save models
    if val_acc > best_acc:
        best_acc = val_acc
        print(f"Best model found at epoch {i + 1}, saving model with val accuracy of {best_acc* 100:7.3f}%")
        torch.save(model.state_dict(), f"{_exp_name}_best.ckpt") # only save best to prevent output memory exceed error
        stale = 0
    else:
        stale += 1
        if stale > patience:
            print(f"No improvment {patience} consecutive epochs, early stopping")
            break
    print('-' * 100)
print(f'\nDuration: {time.time() - start_time:.0f} seconds') # print the time elapsed
# Out:
# epoch:  1  training batch:  200 [  2000/  8000]  loss: 0.70815390  accuracy:  54.650%
# epoch:  1  training batch:  400 [  4000/  8000]  loss: 0.41472548  accuracy:  59.325%
# epoch:  1  training batch:  600 [  6000/  8000]  loss: 0.62217396  accuracy:  61.033%
# epoch:  1  training batch:  800 [  8000/  8000]  loss: 0.48758078  accuracy:  62.663%
# epoch:  1  validation batch:  100 [  1000/  3000]  loss: 0.48758078  accuracy:  69.100%
# epoch:  1  validation batch:  200 [  2000/  3000]  loss: 0.48758078  accuracy:  70.500%
# epoch:  1  validation batch:  300 [  3000/  3000]  loss: 0.48758078  accuracy:  70.400%
# Best model found at epoch 1, saving model with val accuracy of  70.400%
# ----------------------------------------------------------------------------------------------------
# epoch:  2  training batch:  200 [  2000/  8000]  loss: 0.61791575  accuracy:  69.300%
# epoch:  2  training batch:  400 [  4000/  8000]  loss: 0.49898162  accuracy:  70.675%
# epoch:  2  training batch:  600 [  6000/  8000]  loss: 0.63842309  accuracy:  70.983%
# epoch:  2  training batch:  800 [  8000/  8000]  loss: 0.39993387  accuracy:  71.588%
# epoch:  2  validation batch:  100 [  1000/  3000]  loss: 0.39993387  accuracy:  86.600%
# epoch:  2  validation batch:  200 [  2000/  3000]  loss: 0.39993387  accuracy:  87.150%
# epoch:  2  validation batch:  300 [  3000/  3000]  loss: 0.39993387  accuracy:  81.867%
# Best model found at epoch 2, saving model with val accuracy of  81.867%
# ----------------------------------------------------------------------------------------------------
# epoch:  3  training batch:  200 [  2000/  8000]  loss: 0.50808704  accuracy:  74.800%
# epoch:  3  training batch:  400 [  4000/  8000]  loss: 0.46269837  accuracy:  74.350%
# epoch:  3  training batch:  600 [  6000/  8000]  loss: 0.92458457  accuracy:  74.467%
# epoch:  3  training batch:  800 [  8000/  8000]  loss: 0.48470417  accuracy:  74.237%
# epoch:  3  validation batch:  100 [  1000/  3000]  loss: 0.48470417  accuracy:  70.200%
# epoch:  3  validation batch:  200 [  2000/  3000]  loss: 0.48470417  accuracy:  71.500%
# epoch:  3  validation batch:  300 [  3000/  3000]  loss: 0.48470417  accuracy:  73.200%
# ----------------------------------------------------------------------------------------------------
# epoch:  4  training batch:  200 [  2000/  8000]  loss: 0.46216232  accuracy:  75.200%
# epoch:  4  training batch:  400 [  4000/  8000]  loss: 0.67398536  accuracy:  74.275%
# epoch:  4  training batch:  600 [  6000/  8000]  loss: 0.42398730  accuracy:  74.600%
# epoch:  4  training batch:  800 [  8000/  8000]  loss: 0.21867171  accuracy:  74.425%
# epoch:  4  validation batch:  100 [  1000/  3000]  loss: 0.21867171  accuracy:  75.900%
# epoch:  4  validation batch:  200 [  2000/  3000]  loss: 0.21867171  accuracy:  76.700%
# epoch:  4  validation batch:  300 [  3000/  3000]  loss: 0.21867171  accuracy:  76.967%
# ----------------------------------------------------------------------------------------------------
# epoch:  5  training batch:  200 [  2000/  8000]  loss: 0.44791055  accuracy:  77.050%
# epoch:  5  training batch:  400 [  4000/  8000]  loss: 0.50639284  accuracy:  76.150%
# epoch:  5  training batch:  600 [  6000/  8000]  loss: 0.39314741  accuracy:  76.233%
# epoch:  5  training batch:  800 [  8000/  8000]  loss: 0.26729578  accuracy:  76.200%
# epoch:  5  validation batch:  100 [  1000/  3000]  loss: 0.26729578  accuracy:  78.900%
# epoch:  5  validation batch:  200 [  2000/  3000]  loss: 0.26729578  accuracy:  78.950%
# epoch:  5  validation batch:  300 [  3000/  3000]  loss: 0.26729578  accuracy:  78.433%
# ----------------------------------------------------------------------------------------------------
# epoch:  6  training batch:  200 [  2000/  8000]  loss: 1.08216798  accuracy:  76.250%
# epoch:  6  training batch:  400 [  4000/  8000]  loss: 0.41343269  accuracy:  76.025%
# epoch:  6  training batch:  600 [  6000/  8000]  loss: 0.52234328  accuracy:  76.283%
# epoch:  6  training batch:  800 [  8000/  8000]  loss: 0.69523382  accuracy:  76.087%
# epoch:  6  validation batch:  100 [  1000/  3000]  loss: 0.69523382  accuracy:  68.400%
# epoch:  6  validation batch:  200 [  2000/  3000]  loss: 0.69523382  accuracy:  69.050%
# epoch:  6  validation batch:  300 [  3000/  3000]  loss: 0.69523382  accuracy:  72.233%
# ----------------------------------------------------------------------------------------------------
# epoch:  7  training batch:  200 [  2000/  8000]  loss: 0.63635206  accuracy:  77.600%
# epoch:  7  training batch:  400 [  4000/  8000]  loss: 0.82933694  accuracy:  76.600%
# epoch:  7  training batch:  600 [  6000/  8000]  loss: 0.53852212  accuracy:  77.167%
# epoch:  7  training batch:  800 [  8000/  8000]  loss: 0.40814424  accuracy:  76.912%
# epoch:  7  validation batch:  100 [  1000/  3000]  loss: 0.40814424  accuracy:  85.400%
# epoch:  7  validation batch:  200 [  2000/  3000]  loss: 0.40814424  accuracy:  86.450%
# epoch:  7  validation batch:  300 [  3000/  3000]  loss: 0.40814424  accuracy:  83.967%
# Best model found at epoch 7, saving model with val accuracy of  83.967%
# ----------------------------------------------------------------------------------------------------
# epoch:  8  training batch:  200 [  2000/  8000]  loss: 0.46709356  accuracy:  77.750%
# epoch:  8  training batch:  400 [  4000/  8000]  loss: 0.55662841  accuracy:  78.450%
# epoch:  8  training batch:  600 [  6000/  8000]  loss: 0.43249756  accuracy:  77.917%
# epoch:  8  training batch:  800 [  8000/  8000]  loss: 0.21270160  accuracy:  77.825%
# epoch:  8  validation batch:  100 [  1000/  3000]  loss: 0.21270160  accuracy:  77.500%
# epoch:  8  validation batch:  200 [  2000/  3000]  loss: 0.21270160  accuracy:  77.950%
# epoch:  8  validation batch:  300 [  3000/  3000]  loss: 0.21270160  accuracy:  79.067%
# ----------------------------------------------------------------------------------------------------
# epoch:  9  training batch:  200 [  2000/  8000]  loss: 0.35241330  accuracy:  79.200%
# epoch:  9  training batch:  400 [  4000/  8000]  loss: 0.35100350  accuracy:  79.450%
# epoch:  9  training batch:  600 [  6000/  8000]  loss: 0.36332363  accuracy:  79.000%
# epoch:  9  training batch:  800 [  8000/  8000]  loss: 0.55028898  accuracy:  78.738%
# epoch:  9  validation batch:  100 [  1000/  3000]  loss: 0.55028898  accuracy:  80.000%
# epoch:  9  validation batch:  200 [  2000/  3000]  loss: 0.55028898  accuracy:  80.400%
# epoch:  9  validation batch:  300 [  3000/  3000]  loss: 0.55028898  accuracy:  80.300%
# ----------------------------------------------------------------------------------------------------
# epoch: 10  training batch:  200 [  2000/  8000]  loss: 0.43080711  accuracy:  80.250%
# epoch: 10  training batch:  400 [  4000/  8000]  loss: 0.50300229  accuracy:  79.875%
# epoch: 10  training batch:  600 [  6000/  8000]  loss: 0.50322437  accuracy:  80.067%
# epoch: 10  training batch:  800 [  8000/  8000]  loss: 0.35991660  accuracy:  80.037%
# epoch: 10  validation batch:  100 [  1000/  3000]  loss: 0.35991660  accuracy:  89.700%
# epoch: 10  validation batch:  200 [  2000/  3000]  loss: 0.35991660  accuracy:  90.300%
# epoch: 10  validation batch:  300 [  3000/  3000]  loss: 0.35991660  accuracy:  87.133%
# Best model found at epoch 10, saving model with val accuracy of  87.133%
# ----------------------------------------------------------------------------------------------------
# epoch: 11  training batch:  200 [  2000/  8000]  loss: 0.48329526  accuracy:  80.900%
# epoch: 11  training batch:  400 [  4000/  8000]  loss: 0.61515963  accuracy:  80.675%
# epoch: 11  training batch:  600 [  6000/  8000]  loss: 0.30420959  accuracy:  80.500%
# epoch: 11  training batch:  800 [  8000/  8000]  loss: 0.64065605  accuracy:  80.263%
# epoch: 11  validation batch:  100 [  1000/  3000]  loss: 0.64065605  accuracy:  83.600%
# epoch: 11  validation batch:  200 [  2000/  3000]  loss: 0.64065605  accuracy:  84.150%
# epoch: 11  validation batch:  300 [  3000/  3000]  loss: 0.64065605  accuracy:  83.133%
# ----------------------------------------------------------------------------------------------------
# epoch: 12  training batch:  200 [  2000/  8000]  loss: 0.29831922  accuracy:  80.650%
# epoch: 12  training batch:  400 [  4000/  8000]  loss: 0.26500636  accuracy:  80.300%
# epoch: 12  training batch:  600 [  6000/  8000]  loss: 0.35260206  accuracy:  80.767%
# epoch: 12  training batch:  800 [  8000/  8000]  loss: 0.14420457  accuracy:  80.850%
# epoch: 12  validation batch:  100 [  1000/  3000]  loss: 0.14420457  accuracy:  79.800%
# epoch: 12  validation batch:  200 [  2000/  3000]  loss: 0.14420457  accuracy:  79.850%
# epoch: 12  validation batch:  300 [  3000/  3000]  loss: 0.14420457  accuracy:  80.700%
# ----------------------------------------------------------------------------------------------------
# epoch: 13  training batch:  200 [  2000/  8000]  loss: 0.46412712  accuracy:  80.350%
# epoch: 13  training batch:  400 [  4000/  8000]  loss: 0.28497469  accuracy:  80.200%
# epoch: 13  training batch:  600 [  6000/  8000]  loss: 0.31174198  accuracy:  80.667%
# epoch: 13  training batch:  800 [  8000/  8000]  loss: 0.36508489  accuracy:  80.812%
# epoch: 13  validation batch:  100 [  1000/  3000]  loss: 0.36508489  accuracy:  84.500%
# epoch: 13  validation batch:  200 [  2000/  3000]  loss: 0.36508489  accuracy:  84.450%
# epoch: 13  validation batch:  300 [  3000/  3000]  loss: 0.36508489  accuracy:  84.067%
# ----------------------------------------------------------------------------------------------------
# epoch: 14  training batch:  200 [  2000/  8000]  loss: 0.35931161  accuracy:  80.300%
# epoch: 14  training batch:  400 [  4000/  8000]  loss: 0.30341774  accuracy:  80.525%
# epoch: 14  training batch:  600 [  6000/  8000]  loss: 0.17133549  accuracy:  80.383%
# epoch: 14  training batch:  800 [  8000/  8000]  loss: 0.43269491  accuracy:  80.537%
# epoch: 14  validation batch:  100 [  1000/  3000]  loss: 0.43269491  accuracy:  84.100%
# epoch: 14  validation batch:  200 [  2000/  3000]  loss: 0.43269491  accuracy:  83.650%
# epoch: 14  validation batch:  300 [  3000/  3000]  loss: 0.43269491  accuracy:  83.867%
# ----------------------------------------------------------------------------------------------------
# epoch: 15  training batch:  200 [  2000/  8000]  loss: 0.50374252  accuracy:  80.700%
# epoch: 15  training batch:  400 [  4000/  8000]  loss: 0.28341207  accuracy:  80.775%
# epoch: 15  training batch:  600 [  6000/  8000]  loss: 0.33641663  accuracy:  81.150%
# epoch: 15  training batch:  800 [  8000/  8000]  loss: 0.74922192  accuracy:  81.438%
# epoch: 15  validation batch:  100 [  1000/  3000]  loss: 0.74922192  accuracy:  76.600%
# epoch: 15  validation batch:  200 [  2000/  3000]  loss: 0.74922192  accuracy:  77.500%
# epoch: 15  validation batch:  300 [  3000/  3000]  loss: 0.74922192  accuracy:  79.367%
# ----------------------------------------------------------------------------------------------------
# epoch: 16  training batch:  200 [  2000/  8000]  loss: 0.20825061  accuracy:  83.150%
# epoch: 16  training batch:  400 [  4000/  8000]  loss: 0.34869173  accuracy:  82.650%
# epoch: 16  training batch:  600 [  6000/  8000]  loss: 0.28326851  accuracy:  82.717%
# epoch: 16  training batch:  800 [  8000/  8000]  loss: 0.73964530  accuracy:  82.612%
# epoch: 16  validation batch:  100 [  1000/  3000]  loss: 0.73964530  accuracy:  88.000%
# epoch: 16  validation batch:  200 [  2000/  3000]  loss: 0.73964530  accuracy:  87.900%
# epoch: 16  validation batch:  300 [  3000/  3000]  loss: 0.73964530  accuracy:  86.933%
# ----------------------------------------------------------------------------------------------------
# epoch: 17  training batch:  200 [  2000/  8000]  loss: 0.70298302  accuracy:  81.500%
# epoch: 17  training batch:  400 [  4000/  8000]  loss: 0.27798051  accuracy:  81.775%
# epoch: 17  training batch:  600 [  6000/  8000]  loss: 0.52696317  accuracy:  81.517%
# epoch: 17  training batch:  800 [  8000/  8000]  loss: 0.35267869  accuracy:  81.788%
# epoch: 17  validation batch:  100 [  1000/  3000]  loss: 0.35267869  accuracy:  77.100%
# epoch: 17  validation batch:  200 [  2000/  3000]  loss: 0.35267869  accuracy:  77.800%
# epoch: 17  validation batch:  300 [  3000/  3000]  loss: 0.35267869  accuracy:  79.467%
# ----------------------------------------------------------------------------------------------------
# epoch: 18  training batch:  200 [  2000/  8000]  loss: 0.26252618  accuracy:  82.650%
# epoch: 18  training batch:  400 [  4000/  8000]  loss: 0.27479598  accuracy:  82.450%
# epoch: 18  training batch:  600 [  6000/  8000]  loss: 0.35481629  accuracy:  82.133%
# epoch: 18  training batch:  800 [  8000/  8000]  loss: 0.62153560  accuracy:  82.775%
# epoch: 18  validation batch:  100 [  1000/  3000]  loss: 0.62153560  accuracy:  82.500%
# epoch: 18  validation batch:  200 [  2000/  3000]  loss: 0.62153560  accuracy:  83.200%
# epoch: 18  validation batch:  300 [  3000/  3000]  loss: 0.62153560  accuracy:  83.700%
# ----------------------------------------------------------------------------------------------------
# epoch: 19  training batch:  200 [  2000/  8000]  loss: 0.44309989  accuracy:  81.550%
# epoch: 19  training batch:  400 [  4000/  8000]  loss: 0.45082277  accuracy:  82.000%
# epoch: 19  training batch:  600 [  6000/  8000]  loss: 0.33830911  accuracy:  82.317%
# epoch: 19  training batch:  800 [  8000/  8000]  loss: 0.40662998  accuracy:  82.213%
# epoch: 19  validation batch:  100 [  1000/  3000]  loss: 0.40662998  accuracy:  82.000%
# epoch: 19  validation batch:  200 [  2000/  3000]  loss: 0.40662998  accuracy:  83.400%
# epoch: 19  validation batch:  300 [  3000/  3000]  loss: 0.40662998  accuracy:  83.800%
# ----------------------------------------------------------------------------------------------------
# epoch: 20  training batch:  200 [  2000/  8000]  loss: 0.54013491  accuracy:  83.000%
# epoch: 20  training batch:  400 [  4000/  8000]  loss: 0.43640009  accuracy:  83.075%
# epoch: 20  training batch:  600 [  6000/  8000]  loss: 0.41050497  accuracy:  83.333%
# epoch: 20  training batch:  800 [  8000/  8000]  loss: 0.24264228  accuracy:  83.025%
# epoch: 20  validation batch:  100 [  1000/  3000]  loss: 0.24264228  accuracy:  84.400%
# epoch: 20  validation batch:  200 [  2000/  3000]  loss: 0.24264228  accuracy:  85.400%
# epoch: 20  validation batch:  300 [  3000/  3000]  loss: 0.24264228  accuracy:  85.267%
# ----------------------------------------------------------------------------------------------------
# epoch: 21  training batch:  200 [  2000/  8000]  loss: 0.79725897  accuracy:  82.900%
# epoch: 21  training batch:  400 [  4000/  8000]  loss: 0.43470913  accuracy:  82.850%
# epoch: 21  training batch:  600 [  6000/  8000]  loss: 0.31063533  accuracy:  83.000%
# epoch: 21  training batch:  800 [  8000/  8000]  loss: 0.37582621  accuracy:  83.138%
# epoch: 21  validation batch:  100 [  1000/  3000]  loss: 0.37582621  accuracy:  89.600%
# epoch: 21  validation batch:  200 [  2000/  3000]  loss: 0.37582621  accuracy:  89.850%
# epoch: 21  validation batch:  300 [  3000/  3000]  loss: 0.37582621  accuracy:  88.433%
# Best model found at epoch 21, saving model with val accuracy of  88.433%
# ----------------------------------------------------------------------------------------------------
# epoch: 22  training batch:  200 [  2000/  8000]  loss: 0.29216588  accuracy:  84.050%
# epoch: 22  training batch:  400 [  4000/  8000]  loss: 0.56106794  accuracy:  83.550%
# epoch: 22  training batch:  600 [  6000/  8000]  loss: 0.44880420  accuracy:  83.483%
# epoch: 22  training batch:  800 [  8000/  8000]  loss: 0.27746838  accuracy:  83.200%
# epoch: 22  validation batch:  100 [  1000/  3000]  loss: 0.27746838  accuracy:  75.200%
# epoch: 22  validation batch:  200 [  2000/  3000]  loss: 0.27746838  accuracy:  75.950%
# epoch: 22  validation batch:  300 [  3000/  3000]  loss: 0.27746838  accuracy:  78.433%
# ----------------------------------------------------------------------------------------------------
# epoch: 23  training batch:  200 [  2000/  8000]  loss: 0.42609581  accuracy:  82.750%
# epoch: 23  training batch:  400 [  4000/  8000]  loss: 0.47659984  accuracy:  82.400%
# epoch: 23  training batch:  600 [  6000/  8000]  loss: 0.58541191  accuracy:  82.817%
# epoch: 23  training batch:  800 [  8000/  8000]  loss: 0.44844326  accuracy:  82.812%
# epoch: 23  validation batch:  100 [  1000/  3000]  loss: 0.44844326  accuracy:  86.900%
# epoch: 23  validation batch:  200 [  2000/  3000]  loss: 0.44844326  accuracy:  87.250%
# epoch: 23  validation batch:  300 [  3000/  3000]  loss: 0.44844326  accuracy:  86.300%
# ----------------------------------------------------------------------------------------------------
# epoch: 24  training batch:  200 [  2000/  8000]  loss: 0.38170600  accuracy:  83.900%
# epoch: 24  training batch:  400 [  4000/  8000]  loss: 0.09770692  accuracy:  84.500%
# epoch: 24  training batch:  600 [  6000/  8000]  loss: 0.23759072  accuracy:  84.383%
# epoch: 24  training batch:  800 [  8000/  8000]  loss: 0.20654897  accuracy:  83.975%
# epoch: 24  validation batch:  100 [  1000/  3000]  loss: 0.20654897  accuracy:  83.500%
# epoch: 24  validation batch:  200 [  2000/  3000]  loss: 0.20654897  accuracy:  84.850%
# epoch: 24  validation batch:  300 [  3000/  3000]  loss: 0.20654897  accuracy:  85.300%
# ----------------------------------------------------------------------------------------------------
# epoch: 25  training batch:  200 [  2000/  8000]  loss: 0.70309448  accuracy:  85.050%
# epoch: 25  training batch:  400 [  4000/  8000]  loss: 0.52812356  accuracy:  83.875%
# epoch: 25  training batch:  600 [  6000/  8000]  loss: 0.21218458  accuracy:  83.800%
# epoch: 25  training batch:  800 [  8000/  8000]  loss: 0.49952799  accuracy:  83.975%
# epoch: 25  validation batch:  100 [  1000/  3000]  loss: 0.49952799  accuracy:  82.100%
# epoch: 25  validation batch:  200 [  2000/  3000]  loss: 0.49952799  accuracy:  83.250%
# epoch: 25  validation batch:  300 [  3000/  3000]  loss: 0.49952799  accuracy:  84.167%
# ----------------------------------------------------------------------------------------------------
# epoch: 26  training batch:  200 [  2000/  8000]  loss: 0.39576799  accuracy:  84.950%
# epoch: 26  training batch:  400 [  4000/  8000]  loss: 0.53720999  accuracy:  84.725%
# epoch: 26  training batch:  600 [  6000/  8000]  loss: 0.37651902  accuracy:  84.717%
# epoch: 26  training batch:  800 [  8000/  8000]  loss: 0.26944047  accuracy:  84.575%
# epoch: 26  validation batch:  100 [  1000/  3000]  loss: 0.26944047  accuracy:  86.000%
# epoch: 26  validation batch:  200 [  2000/  3000]  loss: 0.26944047  accuracy:  86.800%
# epoch: 26  validation batch:  300 [  3000/  3000]  loss: 0.26944047  accuracy:  86.833%
# ----------------------------------------------------------------------------------------------------
# epoch: 27  training batch:  200 [  2000/  8000]  loss: 0.60767567  accuracy:  84.150%
# epoch: 27  training batch:  400 [  4000/  8000]  loss: 0.34276444  accuracy:  84.025%
# epoch: 27  training batch:  600 [  6000/  8000]  loss: 0.22661602  accuracy:  83.933%
# epoch: 27  training batch:  800 [  8000/  8000]  loss: 0.32511604  accuracy:  84.225%
# epoch: 27  validation batch:  100 [  1000/  3000]  loss: 0.32511604  accuracy:  85.800%
# epoch: 27  validation batch:  200 [  2000/  3000]  loss: 0.32511604  accuracy:  87.300%
# epoch: 27  validation batch:  300 [  3000/  3000]  loss: 0.32511604  accuracy:  87.067%
# ----------------------------------------------------------------------------------------------------
# epoch: 28  training batch:  200 [  2000/  8000]  loss: 0.80586910  accuracy:  84.800%
# epoch: 28  training batch:  400 [  4000/  8000]  loss: 0.44341621  accuracy:  85.100%
# epoch: 28  training batch:  600 [  6000/  8000]  loss: 0.33998331  accuracy:  84.650%
# epoch: 28  training batch:  800 [  8000/  8000]  loss: 0.16811606  accuracy:  84.513%
# epoch: 28  validation batch:  100 [  1000/  3000]  loss: 0.16811606  accuracy:  80.500%
# epoch: 28  validation batch:  200 [  2000/  3000]  loss: 0.16811606  accuracy:  81.300%
# epoch: 28  validation batch:  300 [  3000/  3000]  loss: 0.16811606  accuracy:  83.000%
# ----------------------------------------------------------------------------------------------------
# epoch: 29  training batch:  200 [  2000/  8000]  loss: 0.06446920  accuracy:  86.000%
# epoch: 29  training batch:  400 [  4000/  8000]  loss: 0.27506331  accuracy:  85.900%
# epoch: 29  training batch:  600 [  6000/  8000]  loss: 0.60124254  accuracy:  85.800%
# epoch: 29  training batch:  800 [  8000/  8000]  loss: 0.45021528  accuracy:  85.550%
# epoch: 29  validation batch:  100 [  1000/  3000]  loss: 0.45021528  accuracy:  84.700%
# epoch: 29  validation batch:  200 [  2000/  3000]  loss: 0.45021528  accuracy:  86.000%
# epoch: 29  validation batch:  300 [  3000/  3000]  loss: 0.45021528  accuracy:  86.300%
# ----------------------------------------------------------------------------------------------------
# epoch: 30  training batch:  200 [  2000/  8000]  loss: 0.70134419  accuracy:  86.100%
# epoch: 30  training batch:  400 [  4000/  8000]  loss: 0.11359145  accuracy:  85.675%
# epoch: 30  training batch:  600 [  6000/  8000]  loss: 0.36665088  accuracy:  85.433%
# epoch: 30  training batch:  800 [  8000/  8000]  loss: 0.33149314  accuracy:  85.162%
# epoch: 30  validation batch:  100 [  1000/  3000]  loss: 0.33149314  accuracy:  82.900%
# epoch: 30  validation batch:  200 [  2000/  3000]  loss: 0.33149314  accuracy:  84.200%
# epoch: 30  validation batch:  300 [  3000/  3000]  loss: 0.33149314  accuracy:  84.933%
# ----------------------------------------------------------------------------------------------------
#
# Duration: 2216 seconds

# %% [markdown]
# # Evaluate model performance

# %%
plt.plot(train_losses, label='training loss')
plt.plot(valid_losses, label='validation loss')
plt.title('Loss at the end of each epoch')
plt.legend();

# %%
plt.plot([t/(max_trn_batch * batch_size) for t in train_correct], label='training accuracy')
plt.plot([t/(max_val_batch * batch_size) for t in valid_correct], label='validation accuracy')
plt.title('Accuracy at the end of each epoch')
plt.legend();

# %%
print(valid_correct)
print(f'Valid accuracy: {valid_correct[-1] / max_val_batch * 10:.3f}%')
# Out:
# [2112, 2456, 2196, 2309, 2353, 2167, 2519, 2372, 2409, 2614, 2494, 2421, 2522, 2516, 2381, 2608, 2384, 2511, 2514, 2558, 2653, 2353, 2589, 2559, 2525, 2605, 2612, 2490, 2589, 2548]
# Valid accuracy: 84.933%

# %% [markdown]
# To do prediction for the test dataset, it is the same way as predict validation set and get labels. \
# The label in sampleSubmission.csv is not correct, so I do not do prediction for test.
